# %%
list1=[1,2,3,4,5]
print (list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
list2=['orange','pinappl','apple']
print (list2)
list2.append('mango')
print (list2)
# Out:
# ['orange', 'pinappl', 'apple']
# ['orange', 'pinappl', 'apple', 'mango']

# %%
list3=['red','orange','black']
print (list3)
list3.remove ('orange')
print (list3)
# Out:
# ['red', 'orange', 'black']
# ['red', 'black']

# %%
list4=['red','orange','black']
len (list4)
# Out:
# 3

# %%
tuple1=(1,2,3,4)
print (tuple1)
# Out:
# (1, 2, 3, 4)

# %%
tuple2=('sat','sun','mon','tue','wed','thr','fri')
print (tuple2[0])
# Out:
# sat

# %%
theset={10,10,15,15,0,0}
print (theset)
# Out:
# {0, 10, 15}

# %%
theset1={10,15,0}
print (theset1)
theset1.add(55)
print (theset1)
# Out:
# {0, 10, 15}
# {0, 10, 55, 15}

# %%
dict1 = { "name" : "eslam" ,
          "age" : 39}
print (dict1)
# Out:
# {'name': 'eslam', 'age': 39}

# %%
dict2 = { "name" : "book" ,
          "price" : 100}
print (dict2 ["price"])
# Out:
# 100
